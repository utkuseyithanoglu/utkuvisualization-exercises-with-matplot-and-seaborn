# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_iris=sns.load_dataset("iris")
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df_iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df_iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
a=df_iris.groupby('species')[['sepal_length','sepal_width', 'petal_length', 'petal_width']].mean().round(2)#.sum(axis=1)
b=df_iris.groupby('species')[['sepal_length','sepal_width', 'petal_length', 'petal_width']].mean().round(2).sum(axis=1)
print(a,b)
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa              5.01         3.43          1.46         0.25
# versicolor          5.94         2.77          4.26         1.33
# virginica           6.59         2.97          5.55         2.03 species
# setosa        10.15
# versicolor    14.30
# virginica     17.14
# dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(a,x='sepal_length',y='sepal_width',hue='species')#data yazmana gerek yok ama yazarsan da ok
plt.grid()
plt.xlabel="sepal_length"
plt.ylabel="sepal_width"

# %%
plt.Figure(figsize=(10,5))
sns.barplot(data=a,x='petal_length',y='petal_width',alpha=0.6,hue='species')
plt.grid()
plt.xlabel="p"
plt.title("petal_length")
# Out:
# Text(0.5, 1.0, 'petal_length')

# %%
sns.histplot(data=a,x='species',y='sepal_length')
#bunun yarım gösterme sebebi veri az bunun yerine bar plotla göstermek daha doğru az veriyi
plt.grid()
plt.xlabel='species'
plt.ylabel='sepal_length'
plt.title('specie_sepal_length')
# Out:
# Text(0.5, 1.0, 'specie_sepal_length')

# %%
sns.barplot(a,x='species',y='sepal_length',hue='species',palette='rocket'\
,edgecolor='black',orient='h',saturation=0.1,)#orient yatay saturation yatay 
plt.grid(color='black')

# %%
sns.barplot(a,x='species',y='sepal_length',hue='species',palette='rocket'\
,edgecolor='black',saturation=1)
plt.grid(color='black')
